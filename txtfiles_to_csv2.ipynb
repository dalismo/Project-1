# %%
import pandas as pd

# %%
filepath = "../Project-1/California Mortality (1).txt"
file = pd.read_csv(filepath, delimiter="\t")
file.to_csv("California_Mortality_1.csv")

# %%
filepath_1 = "../Project-1/California_Mortality_1.csv"
cm1_df = pd.read_csv(filepath_1)
cm1_df.head()
# Out:
#    Unnamed: 0 Notes              County  County Code  Gender Gender Code  \
# 0           0   NaN  Alameda County, CA       6001.0  Female           F
# 1           1   NaN  Alameda County, CA       6001.0  Female           F
# 2           2   NaN  Alameda County, CA       6001.0  Female           F
# 3           3   NaN  Alameda County, CA       6001.0  Female           F
# 4           4   NaN  Alameda County, CA       6001.0  Female           F
#
#      Year  Year Code                       Race Race Code  Deaths  Population  \
# 0  2006.0     2006.0  Asian or Pacific Islander      A-PI    46.0    204139.0
# 1  2006.0     2006.0  Black or African American    2054-5    70.0    112599.0
# 2  2006.0     2006.0                      White    2106-3   330.0    410372.0
# 3  2007.0     2007.0  Asian or Pacific Islander      A-PI    42.0    209933.0
# 4  2007.0     2007.0  Black or African American    2054-5    69.0    112100.0
#
#   Crude Rate Age Adjusted Rate % of Total Deaths
# ...

# %%
cm1_df1 = cm1_df.drop(["Unnamed: 0", "Notes"], axis=1)
cm1_df1.head()
# Out:
#                County  County Code  Gender Gender Code    Year  Year Code  \
# 0  Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 1  Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 2  Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 3  Alameda County, CA       6001.0  Female           F  2007.0     2007.0
# 4  Alameda County, CA       6001.0  Female           F  2007.0     2007.0
#
#                         Race Race Code  Deaths  Population Crude Rate  \
# 0  Asian or Pacific Islander      A-PI    46.0    204139.0       22.5
# 1  Black or African American    2054-5    70.0    112599.0       62.2
# 2                      White    2106-3   330.0    410372.0       80.4
# 3  Asian or Pacific Islander      A-PI    42.0    209933.0       20.0
# 4  Black or African American    2054-5    69.0    112100.0       61.6
#
#   Age Adjusted Rate % of Total Deaths
# 0              27.7              0.0%
# ...

# %%
cm1_df1.shape
# Out:
# (1777, 13)

# %%
cm1_df1.dropna()
# Out:
#                   County  County Code  Gender Gender Code    Year  Year Code  \
# 0     Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 1     Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 2     Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 3     Alameda County, CA       6001.0  Female           F  2007.0     2007.0
# 4     Alameda County, CA       6001.0  Female           F  2007.0     2007.0
# ...                  ...          ...     ...         ...     ...        ...
# 1719     Yuba County, CA       6115.0    Male           M  2012.0     2012.0
# 1720     Yuba County, CA       6115.0    Male           M  2013.0     2013.0
# 1721     Yuba County, CA       6115.0    Male           M  2014.0     2014.0
# 1722     Yuba County, CA       6115.0    Male           M  2015.0     2015.0
# 1723     Yuba County, CA       6115.0    Male           M  2016.0     2016.0
#
# ...

# %%
cm1_df1.to_csv("Clean_California_Mortality_1.csv", index=False)

# %%
filepath1 = "../Project-1/California Mortality (2).txt"
file = pd.read_csv(filepath1, delimiter="\t")
file.to_csv("California_Mortality_2.csv")

# %%
filepath_2 = "../Project-1/California_Mortality_2.csv"
cm2_df = pd.read_csv(filepath_2)
cm2_df.head()
# Out:
#    Unnamed: 0 Notes              County  County Code  Gender Gender Code  \
# 0           0   NaN  Alameda County, CA       6001.0  Female           F
# 1           1   NaN  Alameda County, CA       6001.0  Female           F
# 2           2   NaN  Alameda County, CA       6001.0  Female           F
# 3           3   NaN  Alameda County, CA       6001.0  Female           F
# 4           4   NaN  Alameda County, CA       6001.0  Female           F
#
#      Year  Year Code                              Race Race Code  Deaths  \
# 0  2006.0     2006.0  American Indian or Alaska Native    1002-5    17.0
# 1  2006.0     2006.0         Asian or Pacific Islander      A-PI   667.0
# 2  2006.0     2006.0         Black or African American    2054-5  1048.0
# 3  2006.0     2006.0                             White    2106-3  3003.0
# 4  2007.0     2007.0  American Indian or Alaska Native    1002-5    19.0
#
#    Population          Crude Rate   Age Adjusted Rate % of Total Deaths
# ...

# %%
cm1_df2 = cm2_df.drop(["Unnamed: 0", "Notes"], axis=1)
cm1_df2.head()
cm1_df2
# Out:
#                   County  County Code  Gender Gender Code    Year  Year Code  \
# 0     Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 1     Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 2     Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 3     Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 4     Alameda County, CA       6001.0  Female           F  2007.0     2007.0
# ...                  ...          ...     ...         ...     ...        ...
# 3208                 NaN          NaN     NaN         NaN     NaN        NaN
# 3209                 NaN          NaN     NaN         NaN     NaN        NaN
# 3210                 NaN          NaN     NaN         NaN     NaN        NaN
# 3211                 NaN          NaN     NaN         NaN     NaN        NaN
# 3212                 NaN          NaN     NaN         NaN     NaN        NaN
#
# ...

# %%
cm1_df2.dropna()
# Out:
#                   County  County Code  Gender Gender Code    Year  Year Code  \
# 0     Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 1     Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 2     Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 3     Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 4     Alameda County, CA       6001.0  Female           F  2007.0     2007.0
# ...                  ...          ...     ...         ...     ...        ...
# 3156     Yuba County, CA       6115.0    Male           M  2015.0     2015.0
# 3157     Yuba County, CA       6115.0    Male           M  2015.0     2015.0
# 3158     Yuba County, CA       6115.0    Male           M  2016.0     2016.0
# 3159     Yuba County, CA       6115.0    Male           M  2016.0     2016.0
# 3160     Yuba County, CA       6115.0    Male           M  2016.0     2016.0
#
# ...

# %%
cm1_df2.to_csv("Clean_California_Mortality_2.csv", index=False)
