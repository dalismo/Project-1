# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
# Importing data files

pollution_data_df = pd.read_csv("Resources/California_Pollution.csv")
mortality_data_df = pd.read_csv("Resources/California_Mortality.csv")

# %%
pollution_data_df
#pollution_data_df.info()
# Out:
#         Unnamed: 0  State Code  County Code  Site Num                 Address  \
# 0             3516           6           13         2  2956-A TREAT BOULEVARD
# 1             3517           6           13         2  2956-A TREAT BOULEVARD
# 2             3518           6           13         2  2956-A TREAT BOULEVARD
# 3             3519           6           13         2  2956-A TREAT BOULEVARD
# 4             3520           6           13         2  2956-A TREAT BOULEVARD
# ...            ...         ...          ...       ...                     ...
# 397527       44293           6           95         4        304 TUOLUMNE ST.
# 397528       44294           6           95         4        304 TUOLUMNE ST.
# 397529       44295           6           95         4        304 TUOLUMNE ST.
# 397530       44296           6           95         4        304 TUOLUMNE ST.
# 397531       44297           6           95         4        304 TUOLUMNE ST.
#
# ...

# %%
mortality_data_df
# Out:
#                                                   Notes    Year  Year Code  \
# 0                                                   NaN  2006.0     2006.0
# 1                                                   NaN  2006.0     2006.0
# 2                                                   NaN  2006.0     2006.0
# 3                                                   NaN  2006.0     2006.0
# 4                                                   NaN  2006.0     2006.0
# ...                                                 ...     ...        ...
# 6390  resident population that is under one year of ...     NaN        NaN
# 6391  7. Beginning with the 2018 data, changes have ...     NaN        NaN
# 6392  compared to previous practice. In addition, da...     NaN        NaN
# 6393  in information available to individual states ...     NaN        NaN
# 6394  information can be found at: https://www.cdc.g...     NaN        NaN
#
# ...

# %%
mortality_data_df['County'] = mortality_data_df['County'].str.replace(' County, CA', '')
mortality_data_df
#mortality_data_df.info()
# mortality_data_df[["County","State_Abbreviation"]] = mortality_data_df.County.str.split(" ",expand=True)
# Out:
#                                                   Notes    Year  Year Code  \
# 0                                                   NaN  2006.0     2006.0
# 1                                                   NaN  2006.0     2006.0
# 2                                                   NaN  2006.0     2006.0
# 3                                                   NaN  2006.0     2006.0
# 4                                                   NaN  2006.0     2006.0
# ...                                                 ...     ...        ...
# 6390  resident population that is under one year of ...     NaN        NaN
# 6391  7. Beginning with the 2018 data, changes have ...     NaN        NaN
# 6392  compared to previous practice. In addition, da...     NaN        NaN
# 6393  in information available to individual states ...     NaN        NaN
# 6394  information can be found at: https://www.cdc.g...     NaN        NaN
#
# ...

# %%
mortality_data_clean_df = mortality_data_df.drop(["Notes", "Year Code"], axis=1)

# %%
mortality_data_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6395 entries, 0 to 6394
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        6325 non-null   float64
#  1   ICD-10 113 Cause List       6325 non-null   object
#  2   ICD-10 113 Cause List Code  6325 non-null   object
#  3   County                      6325 non-null   object
#  4   County Code                 6325 non-null   float64
#  5   Race                        6325 non-null   object
#  6   Race Code                   6325 non-null   object
#  7   Gender                      6325 non-null   object
#  8   Gender Code                 6325 non-null   object
#  9   Deaths                      6325 non-null   float64
#  10  Population                  6325 non-null   float64
#  11  Crude Rate                  6325 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 599.7+ KB

# %%
mortality_data_clean_df['Year'] = mortality_data_clean_df['Year'].astype(str).replace('\.0', '', regex=True)
mortality_data_clean_df
# Out:
#       Year               ICD-10 113 Cause List ICD-10 113 Cause List Code  \
# 0     2006  #Influenza and pneumonia (J09-J18)                  GR113-076
# 1     2006  #Influenza and pneumonia (J09-J18)                  GR113-076
# 2     2006  #Influenza and pneumonia (J09-J18)                  GR113-076
# 3     2006  #Influenza and pneumonia (J09-J18)                  GR113-076
# 4     2006  #Influenza and pneumonia (J09-J18)                  GR113-076
# ...    ...                                 ...                        ...
# 6390   nan                                 NaN                        NaN
# 6391   nan                                 NaN                        NaN
# 6392   nan                                 NaN                        NaN
# 6393   nan                                 NaN                        NaN
# 6394   nan                                 NaN                        NaN
#
#        County  County Code                       Race Race Code  Gender  \
# ...

# %%
mortality_data_clean_df['ICD-10 113 Cause List'] = mortality_data_clean_df['ICD-10 113 Cause List'].str.replace('#', '')
mortality_data_clean_df
# Out:
#       Year              ICD-10 113 Cause List ICD-10 113 Cause List Code  \
# 0     2006  Influenza and pneumonia (J09-J18)                  GR113-076
# 1     2006  Influenza and pneumonia (J09-J18)                  GR113-076
# 2     2006  Influenza and pneumonia (J09-J18)                  GR113-076
# 3     2006  Influenza and pneumonia (J09-J18)                  GR113-076
# 4     2006  Influenza and pneumonia (J09-J18)                  GR113-076
# ...    ...                                ...                        ...
# 6390   nan                                NaN                        NaN
# 6391   nan                                NaN                        NaN
# 6392   nan                                NaN                        NaN
# 6393   nan                                NaN                        NaN
# 6394   nan                                NaN                        NaN
#
#        County  County Code                       Race Race Code  Gender  \
# ...

# %%
#mortality_data_clean_df['Year'] = mortality_data_clean_df['Year'].str.replace('nan', 'NaN')
#mortality_data_clean_df

# %%
# df.dropna(axis = 0, how = 'all', inplace = True)
# mortality_data_final_df = mortality_data_clean_df.dropna(axis=0, how='all', inplace = True)
# mortality_data_final_df

# %%
# Combine the data into a single dataset
# merged_inner = pd.merge(left=mortality_data_df, right=pollution_data_df, left_on='County', right_on='County')
#merged_df = pd.merge(mortality_data_clean_df, pollution_data_df, how="outer", on=["County"])
#merged_idf

# %%
merged_df = mortality_data_clean_df.combine_first(pollution_data_df)
#merged_df.to_csv("data_merged.csv")
merged_df
# Out:
#                        Address  CO 1st Max Hour  CO 1st Max Value  CO AQI  \
# 0       2956-A TREAT BOULEVARD              4.0               1.3     NaN
# 1       2956-A TREAT BOULEVARD              6.0               0.8     9.0
# 2       2956-A TREAT BOULEVARD              4.0               1.3     NaN
# 3       2956-A TREAT BOULEVARD              6.0               0.8     9.0
# 4       2956-A TREAT BOULEVARD             21.0               1.1     NaN
# ...                        ...              ...               ...     ...
# 397527        304 TUOLUMNE ST.             23.0               0.5     6.0
# 397528        304 TUOLUMNE ST.              1.0               1.6     NaN
# 397529        304 TUOLUMNE ST.              5.0               1.2    14.0
# 397530        304 TUOLUMNE ST.              1.0               1.6     NaN
# 397531        304 TUOLUMNE ST.              5.0               1.2    14.0
#
#          CO Mean           CO Units     City   County  County Code  \
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397532 entries, 0 to 397531
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Address                     397532 non-null  object
#  1   CO 1st Max Hour             397532 non-null  float64
#  2   CO 1st Max Value            397532 non-null  float64
#  3   CO AQI                      198768 non-null  float64
#  4   CO Mean                     397532 non-null  float64
#  5   CO Units                    397532 non-null  object
#  6   City                        397532 non-null  object
#  7   County                      397532 non-null  object
#  8   County Code                 397532 non-null  float64
#  9   Crude Rate                  6325 non-null    object
#  10  Date Local                  397532 non-null  object
#  11  Deaths                      6325 non-null    float64
# ...

# %%
merged_df = merged_df.fillna(0)
merged_df
# Out:
#                        Address  CO 1st Max Hour  CO 1st Max Value  CO AQI  \
# 0       2956-A TREAT BOULEVARD              4.0               1.3     0.0
# 1       2956-A TREAT BOULEVARD              6.0               0.8     9.0
# 2       2956-A TREAT BOULEVARD              4.0               1.3     0.0
# 3       2956-A TREAT BOULEVARD              6.0               0.8     9.0
# 4       2956-A TREAT BOULEVARD             21.0               1.1     0.0
# ...                        ...              ...               ...     ...
# 397527        304 TUOLUMNE ST.             23.0               0.5     6.0
# 397528        304 TUOLUMNE ST.              1.0               1.6     0.0
# 397529        304 TUOLUMNE ST.              5.0               1.2    14.0
# 397530        304 TUOLUMNE ST.              1.0               1.6     0.0
# 397531        304 TUOLUMNE ST.              5.0               1.2    14.0
#
#          CO Mean           CO Units     City   County  County Code  \
# ...

# %%
merged_df.to_csv("Resources/merged_output.csv")
