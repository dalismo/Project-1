# %%
import pandas as pd

# %%
mortality = "Resources/cali_mortality.csv"
mortality_df = pd.read_csv(mortality)
mortality_df
# Out:
#       Unnamed: 0    Year  Year Code               ICD-10 113 Cause List  \
# 0              0  2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# 1              1  2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# 2              2  2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# 3              3  2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# 4              4  2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# ...          ...     ...        ...                                 ...
# 6390        6390     NaN        NaN                                 NaN
# 6391        6391     NaN        NaN                                 NaN
# 6392        6392     NaN        NaN                                 NaN
# 6393        6393     NaN        NaN                                 NaN
# 6394        6394     NaN        NaN                                 NaN
#
#      ICD-10 113 Cause List Code   County  County Code  \
# ...

# %%
mortality_df1 = mortality_df.drop(["Unnamed: 0"], axis=1)
mortality_df1
# Out:
#         Year  Year Code               ICD-10 113 Cause List  \
# 0     2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# 1     2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# 2     2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# 3     2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# 4     2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# ...      ...        ...                                 ...
# 6390     NaN        NaN                                 NaN
# 6391     NaN        NaN                                 NaN
# 6392     NaN        NaN                                 NaN
# 6393     NaN        NaN                                 NaN
# 6394     NaN        NaN                                 NaN
#
#      ICD-10 113 Cause List Code   County  County Code  \
# 0                     GR113-076  Alameda       6001.0
# 1                     GR113-076  Alameda       6001.0
# 2                     GR113-076  Alameda       6001.0
# ...

# %%
mortality_df1.dropna()
# Out:
#         Year  Year Code                              ICD-10 113 Cause List  \
# 0     2006.0     2006.0                 #Influenza and pneumonia (J09-J18)
# 1     2006.0     2006.0                 #Influenza and pneumonia (J09-J18)
# 2     2006.0     2006.0                 #Influenza and pneumonia (J09-J18)
# 3     2006.0     2006.0                 #Influenza and pneumonia (J09-J18)
# 4     2006.0     2006.0                 #Influenza and pneumonia (J09-J18)
# ...      ...        ...                                                ...
# 6320  2016.0     2016.0  Other diseases of respiratory system (J00-J06,...
# 6321  2016.0     2016.0  Other diseases of respiratory system (J00-J06,...
# 6322  2016.0     2016.0  Other diseases of respiratory system (J00-J06,...
# 6323  2016.0     2016.0  Other diseases of respiratory system (J00-J06,...
# 6324  2016.0     2016.0  Other diseases of respiratory system (J00-J06,...
#
#      ICD-10 113 Cause List Code      County  County Code  \
# ...

# %%
mortality_df2 = mortality_df1.drop(["County Code", "State_Abbreviation", "Year Code"], axis=1)
mortality_df2.dropna()
# Out:
#         Year                              ICD-10 113 Cause List  \
# 0     2006.0                 #Influenza and pneumonia (J09-J18)
# 1     2006.0                 #Influenza and pneumonia (J09-J18)
# 2     2006.0                 #Influenza and pneumonia (J09-J18)
# 3     2006.0                 #Influenza and pneumonia (J09-J18)
# 4     2006.0                 #Influenza and pneumonia (J09-J18)
# ...      ...                                                ...
# 6320  2016.0  Other diseases of respiratory system (J00-J06,...
# 6321  2016.0  Other diseases of respiratory system (J00-J06,...
# 6322  2016.0  Other diseases of respiratory system (J00-J06,...
# 6323  2016.0  Other diseases of respiratory system (J00-J06,...
# 6324  2016.0  Other diseases of respiratory system (J00-J06,...
#
#      ICD-10 113 Cause List Code      County                       Race  \
# 0                     GR113-076     Alameda  Asian or Pacific Islander
# ...

# %%
mortality_df2.replace(to_replace="Unreliable", value=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-8cb38bf89459> in <module>
# ----> 1 mortality_df2["Crude Rate"](to_replace="Unreliable", value=0)
#
# TypeError: 'Series' object is not callable

# %%
pollution = "Resources/California_Pollution.csv"
pollution_df = pd.read_csv(pollution)
pollution_df

# %%
pollution_df1 = pollution_df.fillna(0)
pollution_df1.drop(["Unnamed: 0"], axis=1)

# %%
merged_data = pd.merge(pollution_df1, mortality_df1, how="inner", on="County")
