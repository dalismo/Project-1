# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
# Importing data files

pollution_data_df = pd.read_csv("Resources/California_Pollution.csv")
mortality_data_df = pd.read_csv("Resources/California_Mortality.csv")

# %%
pollution_data_df
# pollution_data_df.info()
# Out:
#         Unnamed: 0  State Code  County Code  Site Num                 Address  \
# 0             3516           6           13         2  2956-A TREAT BOULEVARD
# 1             3517           6           13         2  2956-A TREAT BOULEVARD
# 2             3518           6           13         2  2956-A TREAT BOULEVARD
# 3             3519           6           13         2  2956-A TREAT BOULEVARD
# 4             3520           6           13         2  2956-A TREAT BOULEVARD
# ...            ...         ...          ...       ...                     ...
# 397527       44293           6           95         4        304 TUOLUMNE ST.
# 397528       44294           6           95         4        304 TUOLUMNE ST.
# 397529       44295           6           95         4        304 TUOLUMNE ST.
# 397530       44296           6           95         4        304 TUOLUMNE ST.
# 397531       44297           6           95         4        304 TUOLUMNE ST.
#
# ...

# %%
mortality_data_df
# Out:
#                                                   Notes    Year  Year Code  \
# 0                                                   NaN  2006.0     2006.0
# 1                                                   NaN  2006.0     2006.0
# 2                                                   NaN  2006.0     2006.0
# 3                                                   NaN  2006.0     2006.0
# 4                                                   NaN  2006.0     2006.0
# ...                                                 ...     ...        ...
# 6390  resident population that is under one year of ...     NaN        NaN
# 6391  7. Beginning with the 2018 data, changes have ...     NaN        NaN
# 6392  compared to previous practice. In addition, da...     NaN        NaN
# 6393  in information available to individual states ...     NaN        NaN
# 6394  information can be found at: https://www.cdc.g...     NaN        NaN
#
# ...

# %%
mortality_data_df['County'] = mortality_data_df['County'].str.split(' ').str[0]
mortality_data_df
mortality_data_df.info()
# mortality_data_df[["County","State_Abbreviation"]] = mortality_data_df.County.str.split(" ",expand=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6395 entries, 0 to 6394
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Notes                       70 non-null     object
#  1   Year                        6325 non-null   float64
#  2   Year Code                   6325 non-null   float64
#  3   ICD-10 113 Cause List       6325 non-null   object
#  4   ICD-10 113 Cause List Code  6325 non-null   object
#  5   County                      6325 non-null   object
#  6   County Code                 6325 non-null   float64
#  7   Race                        6325 non-null   object
#  8   Race Code                   6325 non-null   object
#  9   Gender                      6325 non-null   object
#  10  Gender Code                 6325 non-null   object
#  11  Deaths                      6325 non-null   float64
#  12  Population                  6325 non-null   float64
# ...

# %%
mortality_data_clean_df = mortality_data_df.drop(["Notes"], axis=1)
mortality_data_clean_df.dropna(how='all')
mortality_data_clean_df
# Out:
#         Year  Year Code               ICD-10 113 Cause List  \
# 0     2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# 1     2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# 2     2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# 3     2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# 4     2006.0     2006.0  #Influenza and pneumonia (J09-J18)
# ...      ...        ...                                 ...
# 6390     NaN        NaN                                 NaN
# 6391     NaN        NaN                                 NaN
# 6392     NaN        NaN                                 NaN
# 6393     NaN        NaN                                 NaN
# 6394     NaN        NaN                                 NaN
#
#      ICD-10 113 Cause List Code   County  County Code  \
# 0                     GR113-076  Alameda       6001.0
# 1                     GR113-076  Alameda       6001.0
# 2                     GR113-076  Alameda       6001.0
# ...

# %%
merged_df = mortality_data_df.combine_first(pollution_data_df)
merged_df.to_csv("data_merged.csv")
print(merged_df)
# Out:
#                        Address  CO 1st Max Hour  CO 1st Max Value  CO AQI  \
# 0       2956-A TREAT BOULEVARD              4.0               1.3     NaN
# 1       2956-A TREAT BOULEVARD              6.0               0.8     9.0
# 2       2956-A TREAT BOULEVARD              4.0               1.3     NaN
# 3       2956-A TREAT BOULEVARD              6.0               0.8     9.0
# 4       2956-A TREAT BOULEVARD             21.0               1.1     NaN
# ...                        ...              ...               ...     ...
# 397527        304 TUOLUMNE ST.             23.0               0.5     6.0
# 397528        304 TUOLUMNE ST.              1.0               1.6     NaN
# 397529        304 TUOLUMNE ST.              5.0               1.2    14.0
# 397530        304 TUOLUMNE ST.              1.0               1.6     NaN
# 397531        304 TUOLUMNE ST.              5.0               1.2    14.0
#
#          CO Mean           CO Units     City   County  County Code  \
# ...

# %%
# Combine the data into a single dataset
# merged_inner = pd.merge(left=mortality_data_df, right=pollution_data_df, left_on='County', right_on='County')
# merged_inner = pd.merge(mortality_data_df, pollution_data_df, how="outer", on=["County"])
# merged_inner
# merged_inner.to_csv('merged_inner.csv')
# merged_inner
