# %%
# Import modules
import numpy as np
import pandas as pd

# %%
# Set path for file and open California Mortality 1 CSV 
filepath = "../Project-1/California Mortality1.txt"
file = pd.read_csv(filepath, delimiter="\t")
file.to_csv("California_Mortality_1.csv", index=False)

# %%
# Create dataframe for California Mortality 1
mortality_csv = "../Project-1/California_Mortality_1.csv"
cali_mortality_df = pd.read_csv(mortality_csv)
cali_mortality_df.head()
# Out:
#   Notes              County  County Code  Gender Gender Code    Year  \
# 0   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 1   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 2   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 3   NaN  Alameda County, CA       6001.0  Female           F  2007.0
# 4   NaN  Alameda County, CA       6001.0  Female           F  2007.0
#
#    Year Code                       Race Race Code  Deaths  Population  \
# 0     2006.0  Asian or Pacific Islander      A-PI    46.0    204139.0
# 1     2006.0  Black or African American    2054-5    70.0    112599.0
# 2     2006.0                      White    2106-3   330.0    410372.0
# 3     2007.0  Asian or Pacific Islander      A-PI    42.0    209933.0
# 4     2007.0  Black or African American    2054-5    69.0    112100.0
#
#   Crude Rate Age Adjusted Rate % of Total Deaths
# 0       22.5              27.7              0.0%
# ...

# %%
# Drop NaN column
cali_mortality_clean = cali_mortality_df.drop(["Notes"], axis=1)
cali_mortality_clean.dropna
cali_mortality_clean.head()
# Out:
#                County  County Code  Gender Gender Code    Year  Year Code  \
# 0  Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 1  Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 2  Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 3  Alameda County, CA       6001.0  Female           F  2007.0     2007.0
# 4  Alameda County, CA       6001.0  Female           F  2007.0     2007.0
#
#                         Race Race Code  Deaths  Population Crude Rate  \
# 0  Asian or Pacific Islander      A-PI    46.0    204139.0       22.5
# 1  Black or African American    2054-5    70.0    112599.0       62.2
# 2                      White    2106-3   330.0    410372.0       80.4
# 3  Asian or Pacific Islander      A-PI    42.0    209933.0       20.0
# 4  Black or African American    2054-5    69.0    112100.0       61.6
#
#   Age Adjusted Rate % of Total Deaths
# 0              27.7              0.0%
# ...

# %%
# Set path for file and open California Mortality 2 CSV 
filepath2 = "../Project-1/California Mortality2.txt"
file2 = pd.read_csv(filepath2, delimiter="\t")
file2.to_csv("California_Mortality_2.csv", index=False)

# %%
# Create dataframe for California Mortality 2
mortality2_csv = "../Project-1/California_Mortality_2.csv"
cali_mortality2_df = pd.read_csv(mortality2_csv)
cali_mortality2_df.head()
# Out:
#   Notes              County  County Code  Gender Gender Code    Year  \
# 0   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 1   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 2   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 3   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 4   NaN  Alameda County, CA       6001.0  Female           F  2007.0
#
#    Year Code                              Race Race Code  Deaths  Population  \
# 0     2006.0  American Indian or Alaska Native    1002-5    17.0      9043.0
# 1     2006.0         Asian or Pacific Islander      A-PI   667.0    204139.0
# 2     2006.0         Black or African American    2054-5  1048.0    112599.0
# 3     2006.0                             White    2106-3  3003.0    410372.0
# 4     2007.0  American Indian or Alaska Native    1002-5    19.0      9388.0
#
#            Crude Rate   Age Adjusted Rate % of Total Deaths
# ...

# %%
# Drop NaN column
cali_mortality2_clean = cali_mortality2_df.drop(["Notes"], axis=1)
cali_mortality2_clean.dropna
cali_mortality2_clean.head()
# Out:
#                County  County Code  Gender Gender Code    Year  Year Code  \
# 0  Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 1  Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 2  Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 3  Alameda County, CA       6001.0  Female           F  2006.0     2006.0
# 4  Alameda County, CA       6001.0  Female           F  2007.0     2007.0
#
#                                Race Race Code  Deaths  Population  \
# 0  American Indian or Alaska Native    1002-5    17.0      9043.0
# 1         Asian or Pacific Islander      A-PI   667.0    204139.0
# 2         Black or African American    2054-5  1048.0    112599.0
# 3                             White    2106-3  3003.0    410372.0
# 4  American Indian or Alaska Native    1002-5    19.0      9388.0
#
#            Crude Rate   Age Adjusted Rate % of Total Deaths
# 0  188.0 (Unreliable)  364.4 (Unreliable)              0.0%
# ...
