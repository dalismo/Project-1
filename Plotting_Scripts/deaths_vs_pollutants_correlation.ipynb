# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import Image
from scipy.stats import sem
from scipy.stats import linregress

# %%
mortality_ca = pd.read_csv("Resources/mortality_2006_2010_clean.csv")
pollution_ca = pd.read_csv("Resources/pollution_2006_2010.csv")

# %%
diseases = mortality_ca["ICD-10 113 Cause List"].unique().tolist()
print(diseases, len(diseases))
# Out:
# ['Influenza and pneumonia (J09-J18)', 'Pneumonia (J12-J18)', 'Chronic lower respiratory diseases (J40-J47)', 'Bronchitis, chronic and unspecified (J40-J42)', 'Emphysema (J43)', 'Asthma (J45-J46)', 'Other chronic lower respiratory diseases (J44,J47)', 'Pneumonitis due to solids and liquids (J69)', 'Other diseases of respiratory system (J00-J06,J30- J39,J67,J70-J98)', 'Influenza (J09-J11)'] 10

# %%
counties_list = pollution_ca["County"].unique().tolist()
print(counties_list, len(counties_list))
# Out:
# ['Contra Costa', 'Humboldt', 'Imperial', 'Los Angeles', 'Orange', 'Riverside', 'Sacramento', 'San Bernardino', 'San Diego', 'San Francisco', 'Santa Barbara', 'Santa Cruz', 'Solano', 'Alameda', 'Fresno', 'Santa Clara'] 16

# %%
clrd_mortality = mortality_ca[mortality_ca["ICD-10 113 Cause List"] == 
                                         "Chronic lower respiratory diseases (J40-J47)"]
# clrd_mortality.head()

# %%
grouped_clrd = clrd_mortality.groupby(["County", "Year"])["Deaths"].agg([np.sum])
grouped_clrd1 = grouped_clrd.rename(columns={"sum": "Death"})
grouped_clrd1
# Out:
#               Death
# County  Year
# Alameda 2006  422.0
#         2007  405.0
#         2008  455.0
#         2009  419.0
#         2010  399.0
# ...             ...
# Solano  2006  143.0
#         2007  127.0
#         2008  125.0
#         2009  137.0
#         2010  163.0
#
# [80 rows x 1 columns]

# %%
# Death by county
grouped_clrd2 = grouped_clrd1.reset_index()
grouped_clrd2
# Out:
#      County  Year  Death
# 0   Alameda  2006  422.0
# 1   Alameda  2007  405.0
# 2   Alameda  2008  455.0
# 3   Alameda  2009  419.0
# 4   Alameda  2010  399.0
# ..      ...   ...    ...
# 75   Solano  2006  143.0
# 76   Solano  2007  127.0
# 77   Solano  2008  125.0
# 78   Solano  2009  137.0
# 79   Solano  2010  163.0
#
# [80 rows x 3 columns]

# %%
x = grouped_clrd2

# %%
x
# Out:
#      County  Year  Death
# 0   Alameda  2006  422.0
# 1   Alameda  2007  405.0
# 2   Alameda  2008  455.0
# 3   Alameda  2009  419.0
# 4   Alameda  2010  399.0
# ..      ...   ...    ...
# 75   Solano  2006  143.0
# 76   Solano  2007  127.0
# 77   Solano  2008  125.0
# 78   Solano  2009  137.0
# 79   Solano  2010  163.0
#
# [80 rows x 3 columns]

# %%
total_deaths_by_county = x.groupby(["County"]).sum()

# %%
total_deaths_by_county1 = total_deaths_by_county.reset_index()
total_deaths_by_county1 = total_deaths_by_county1.drop("Year",1)
total_deaths_by_county1
# Out:
#             County    Death
# 0          Alameda   2100.0
# 1     Contra Costa   1933.0
# 2           Fresno   1367.0
# 3         Humboldt    402.0
# 4         Imperial    193.0
# 5      Los Angeles  14468.0
# 6           Orange   4434.0
# 7        Riverside   4533.0
# 8       Sacramento   2751.0
# 9   San Bernardino   4017.0
# 10       San Diego   5115.0
# 11   San Francisco   1089.0
# 12   Santa Barbara    693.0
# 13     Santa Clara   2032.0
# 14      Santa Cruz    418.0
# 15          Solano    695.0

# %%
pollution_ca.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        County     City  Year          NO2 Units  \
# 0      216292        216292  Contra Costa  Concord  2006  Parts per billion
# 1      216293        216293  Contra Costa  Concord  2006  Parts per billion
# 2      216294        216294  Contra Costa  Concord  2006  Parts per billion
# 3      216295        216295  Contra Costa  Concord  2006  Parts per billion
# 4      216296        216296  Contra Costa  Concord  2006  Parts per billion
#
#     NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  ...  \
# 0   9.478261               21.0                 2       20  ...
# 1   9.478261               21.0                 2       20  ...
# 2   9.478261               21.0                 2       20  ...
# 3   9.478261               21.0                 2       20  ...
# 4  11.521739               20.0                 8       19  ...
#
#            SO2 Units  SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour  SO2 AQI  \
# 0  Parts per billion  0.045455                1.0                18      1.0
# 1  Parts per billion  0.045455                1.0                18      1.0
# 2  Parts per billion  0.042857                0.3                20      NaN
# 3  Parts per billion  0.042857                0.3                20      NaN
# 4  Parts per billion  0.227273                2.0                 5      3.0
#
#             CO Units   CO Mean  CO 1st Max Value  CO 1st Max Hour  CO AQI
# 0  Parts per million  0.395652               0.7                9     NaN
# 1  Parts per million  0.388889               0.5                6     6.0
# 2  Parts per million  0.395652               0.7                9     NaN
# 3  Parts per million  0.388889               0.5                6     6.0
# 4  Parts per million  0.413043               0.6                0     NaN
#
# [5 rows x 25 columns]

# %%
carbon_monoxide_pollutants = pollution_ca.groupby("County")["CO AQI"].agg([np.sum])
carbon_monoxide_pollutants1 = carbon_monoxide_pollutants.rename(columns={"sum": "CO AQI"})
carbon_monoxide_pollutants2 = carbon_monoxide_pollutants1.reset_index()
carbon_monoxide_pollutants2
# Out:
#             County    CO AQI
# 0          Alameda   12156.0
# 1     Contra Costa   58074.0
# 2           Fresno   16522.0
# 3         Humboldt   11549.0
# 4         Imperial   50846.0
# 5      Los Angeles  120576.0
# 6           Orange   19764.0
# 7        Riverside   28642.0
# 8       Sacramento   42322.0
# 9   San Bernardino   30728.0
# 10       San Diego   97376.0
# 11   San Francisco   15454.0
# 12   Santa Barbara   31642.0
# 13     Santa Clara    9166.0
# 14      Santa Cruz   13078.0
# 15          Solano   30112.0

# %%
co_merge = pd.merge(carbon_monoxide_pollutants2, total_deaths_by_county1)
co_merge
# Out:
#             County    CO AQI    Death
# 0          Alameda   12156.0   2100.0
# 1     Contra Costa   58074.0   1933.0
# 2           Fresno   16522.0   1367.0
# 3         Humboldt   11549.0    402.0
# 4         Imperial   50846.0    193.0
# 5      Los Angeles  120576.0  14468.0
# 6           Orange   19764.0   4434.0
# 7        Riverside   28642.0   4533.0
# 8       Sacramento   42322.0   2751.0
# 9   San Bernardino   30728.0   4017.0
# 10       San Diego   97376.0   5115.0
# 11   San Francisco   15454.0   1089.0
# 12   Santa Barbara   31642.0    693.0
# 13     Santa Clara    9166.0   2032.0
# 14      Santa Cruz   13078.0    418.0
# 15          Solano   30112.0    695.0

# %%
x_values = co_merge["CO AQI"]
y_values = co_merge["Death"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,5))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", alpha=0.6, edgecolor="black", s=50)
plt.plot(x_values,regress_values,"r-", alpha=0.5)
plt.annotate(line_eq,(80000,800),fontsize=12,color="red")
plt.xlabel("Total Carbon Monoxide (CO) AQI")
plt.ylabel("Total Deaths")
plt.title("Carbon Monoxide AQI vs Total Deaths from CLRD | 2006-2010")
plt.show()

# %%
corr = co_merge.corr(method="pearson")
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style  type="text/css" >
#     #T_943ec646_baac_11eb_8d62_a860b6348389row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_943ec646_baac_11eb_8d62_a860b6348389row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_943ec646_baac_11eb_8d62_a860b6348389row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_943ec646_baac_11eb_8d62_a860b6348389row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_943ec646_baac_11eb_8d62_a860b6348389" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CO AQI</th>        <th class="col_heading level0 col1" >Death</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_943ec646_baac_11eb_8d62_a860b6348389level0_row0" class="row_heading level0 row0" >CO AQI</th>
#                         <td id="T_943ec646_baac_11eb_8d62_a860b6348389row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_943ec646_baac_11eb_8d62_a860b6348389row0_col1" class="data row0 col1" >0.754385</td>
#             </tr>
#             <tr>
#                         <th id="T_943ec646_baac_11eb_8d62_a860b6348389level0_row1" class="row_heading level0 row1" >Death</th>
#                         <td id="T_943ec646_baac_11eb_8d62_a860b6348389row1_col0" class="data row1 col0" >0.754385</td>
#                         <td id="T_943ec646_baac_11eb_8d62_a860b6348389row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
print(f"The r-value for Carbon Monoxide (CO) is: {rvalue}")
# Out:
# The r-value for Carbon Monoxide (CO) is: 0.7543850834952978

# %%
nitrogen_dioxide_pollutants = pollution_ca.groupby("County")["NO2 AQI"].agg([np.sum])
nitrogen_dioxide_pollutants1 = nitrogen_dioxide_pollutants.rename(columns={"sum": "NO2 AQI"})
nitrogen_dioxide_pollutants2 = nitrogen_dioxide_pollutants1.reset_index()
nitrogen_dioxide_pollutants2
# Out:
#             County  NO2 AQI
# 0          Alameda   103352
# 1     Contra Costa   419036
# 2           Fresno   151956
# 3         Humboldt    43046
# 4         Imperial   227724
# 5      Los Angeles  1043904
# 6           Orange   172436
# 7        Riverside   213462
# 8       Sacramento   271950
# 9   San Bernardino   392084
# 10       San Diego   600320
# 11   San Francisco   118876
# 12   Santa Barbara   201836
# 13     Santa Clara    74284
# 14      Santa Cruz    44940
# 15          Solano   174290

# %%
no2_merge = pd.merge(nitrogen_dioxide_pollutants2, total_deaths_by_county1)
no2_merge
# Out:
#             County  NO2 AQI    Death
# 0          Alameda   103352   2100.0
# 1     Contra Costa   419036   1933.0
# 2           Fresno   151956   1367.0
# 3         Humboldt    43046    402.0
# 4         Imperial   227724    193.0
# 5      Los Angeles  1043904  14468.0
# 6           Orange   172436   4434.0
# 7        Riverside   213462   4533.0
# 8       Sacramento   271950   2751.0
# 9   San Bernardino   392084   4017.0
# 10       San Diego   600320   5115.0
# 11   San Francisco   118876   1089.0
# 12   Santa Barbara   201836    693.0
# 13     Santa Clara    74284   2032.0
# 14      Santa Cruz    44940    418.0
# 15          Solano   174290    695.0

# %%
x_values = no2_merge["NO2 AQI"]
y_values = no2_merge["Death"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,5))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", alpha=0.6, edgecolor="black", s=50)
plt.plot(x_values,regress_values,"r-", alpha=0.5)
plt.annotate(line_eq,(800000,8000),fontsize=12,color="red")
plt.xlabel("Total Nitrogen Dioxide (NO2) AQI")
plt.ylabel("Total Deaths")
plt.title("Nitrogen Dioxide AQI vs Total Deaths from CLRD | 2006-2010")
plt.show()

# %%
corr = no2_merge.corr(method="pearson")
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style  type="text/css" >
#     #T_94928d58_baac_11eb_b744_a860b6348389row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_94928d58_baac_11eb_b744_a860b6348389row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_94928d58_baac_11eb_b744_a860b6348389row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_94928d58_baac_11eb_b744_a860b6348389row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_94928d58_baac_11eb_b744_a860b6348389" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >NO2 AQI</th>        <th class="col_heading level0 col1" >Death</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_94928d58_baac_11eb_b744_a860b6348389level0_row0" class="row_heading level0 row0" >NO2 AQI</th>
#                         <td id="T_94928d58_baac_11eb_b744_a860b6348389row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_94928d58_baac_11eb_b744_a860b6348389row0_col1" class="data row0 col1" >0.882778</td>
#             </tr>
#             <tr>
#                         <th id="T_94928d58_baac_11eb_b744_a860b6348389level0_row1" class="row_heading level0 row1" >Death</th>
#                         <td id="T_94928d58_baac_11eb_b744_a860b6348389row1_col0" class="data row1 col0" >0.882778</td>
#                         <td id="T_94928d58_baac_11eb_b744_a860b6348389row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
print(f"The r-value for Nitrogen Dioxide (NO2) is: {rvalue}")
# Out:
# The r-value for Nitrogen Dioxide (NO2) is: 0.8827775793559318

# %%
sulphur_dioxide_pollutants = pollution_ca.groupby("County")["SO2 AQI"].agg([np.sum])
sulphur_dioxide_pollutants1 = sulphur_dioxide_pollutants.rename(columns={"sum": "SO2 AQI"})
sulphur_dioxide_pollutants2 = sulphur_dioxide_pollutants1.reset_index()
sulphur_dioxide_pollutants2
# Out:
#             County  SO2 AQI
# 0          Alameda   7328.0
# 1     Contra Costa  58900.0
# 2           Fresno   7206.0
# 3         Humboldt   2250.0
# 4         Imperial  11612.0
# 5      Los Angeles  63070.0
# 6           Orange  10450.0
# 7        Riverside   9134.0
# 8       Sacramento  10149.0
# 9   San Bernardino  15066.0
# 10       San Diego  58212.0
# 11   San Francisco   9530.0
# 12   Santa Barbara  21215.0
# 13     Santa Clara   1450.0
# 14      Santa Cruz   8620.0
# 15          Solano  18509.0

# %%
so2_merge = pd.merge(sulphur_dioxide_pollutants2, total_deaths_by_county1)
so2_merge
# Out:
#             County  SO2 AQI    Death
# 0          Alameda   7328.0   2100.0
# 1     Contra Costa  58900.0   1933.0
# 2           Fresno   7206.0   1367.0
# 3         Humboldt   2250.0    402.0
# 4         Imperial  11612.0    193.0
# 5      Los Angeles  63070.0  14468.0
# 6           Orange  10450.0   4434.0
# 7        Riverside   9134.0   4533.0
# 8       Sacramento  10149.0   2751.0
# 9   San Bernardino  15066.0   4017.0
# 10       San Diego  58212.0   5115.0
# 11   San Francisco   9530.0   1089.0
# 12   Santa Barbara  21215.0    693.0
# 13     Santa Clara   1450.0   2032.0
# 14      Santa Cruz   8620.0    418.0
# 15          Solano  18509.0    695.0

# %%
x_values = so2_merge["SO2 AQI"]
y_values = so2_merge["Death"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,5))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", alpha=0.6, edgecolor="black", s=50)
plt.plot(x_values,regress_values,"r-", alpha=0.5)
plt.annotate(line_eq,(40000,8000),fontsize=12,color="red")
plt.xlabel("Total Sulphur Dioxide (SO2) AQI")
plt.ylabel("Total Deaths")
plt.title("Sulphur Dioxide AQI vs Total Deaths from CLRD | 2006-2010")
plt.show()

# %%
corr = so2_merge.corr(method="pearson")
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style  type="text/css" >
#     #T_5f2763a2_baad_11eb_9ccb_a860b6348389row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5f2763a2_baad_11eb_9ccb_a860b6348389row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5f2763a2_baad_11eb_9ccb_a860b6348389row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5f2763a2_baad_11eb_9ccb_a860b6348389row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_5f2763a2_baad_11eb_9ccb_a860b6348389" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SO2 AQI</th>        <th class="col_heading level0 col1" >Death</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5f2763a2_baad_11eb_9ccb_a860b6348389level0_row0" class="row_heading level0 row0" >SO2 AQI</th>
#                         <td id="T_5f2763a2_baad_11eb_9ccb_a860b6348389row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_5f2763a2_baad_11eb_9ccb_a860b6348389row0_col1" class="data row0 col1" >0.617040</td>
#             </tr>
#             <tr>
#                         <th id="T_5f2763a2_baad_11eb_9ccb_a860b6348389level0_row1" class="row_heading level0 row1" >Death</th>
#                         <td id="T_5f2763a2_baad_11eb_9ccb_a860b6348389row1_col0" class="data row1 col0" >0.617040</td>
#                         <td id="T_5f2763a2_baad_11eb_9ccb_a860b6348389row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
print(f"The r-value for Sulphur Dioxide (SO2) is: {rvalue}")
# Out:
# The r-value for Sulphur Dioxide (SO2) is: 0.6170401313230505

# %%
ozone_pollutants = pollution_ca.groupby("County")["O3 AQI"].agg([np.sum])
ozone_pollutants1 = ozone_pollutants.rename(columns={"sum": "O3 AQI"})
ozone_pollutants2 = ozone_pollutants1.reset_index()
ozone_pollutants2
# Out:
#             County  O3 AQI
# 0          Alameda   97980
# 1     Contra Costa  756928
# 2           Fresno  309880
# 3         Humboldt  130782
# 4         Imperial  274550
# 5      Los Angeles  955288
# 6           Orange  248256
# 7        Riverside  357172
# 8       Sacramento  470606
# 9   San Bernardino  550986
# 10       San Diego  634232
# 11   San Francisco  103280
# 12   Santa Barbara  942084
# 13     Santa Clara   84352
# 14      Santa Cruz  155784
# 15          Solano  282424

# %%
o3_merge = pd.merge(ozone_pollutants2, total_deaths_by_county1)
o3_merge
# Out:
#             County  O3 AQI    Death
# 0          Alameda   97980   2100.0
# 1     Contra Costa  756928   1933.0
# 2           Fresno  309880   1367.0
# 3         Humboldt  130782    402.0
# 4         Imperial  274550    193.0
# 5      Los Angeles  955288  14468.0
# 6           Orange  248256   4434.0
# 7        Riverside  357172   4533.0
# 8       Sacramento  470606   2751.0
# 9   San Bernardino  550986   4017.0
# 10       San Diego  634232   5115.0
# 11   San Francisco  103280   1089.0
# 12   Santa Barbara  942084    693.0
# 13     Santa Clara   84352   2032.0
# 14      Santa Cruz  155784    418.0
# 15          Solano  282424    695.0

# %%
x_values = o3_merge["O3 AQI"]
y_values = o3_merge["Death"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,5))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", alpha=0.6, edgecolor="black", s=50)
plt.plot(x_values,regress_values,"r-", alpha=0.5)
plt.annotate(line_eq,(600000,10000),fontsize=12,color="red")
plt.xlabel("Total Ozone (O3) AQI")
plt.ylabel("Total Deaths")
plt.title("Ozone AQI vs Total Deaths from CLRD | 2006-2010")
plt.show()

# %%
corr = o3_merge.corr(method="pearson")
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style  type="text/css" >
#     #T_5d6e7194_baae_11eb_b74e_a860b6348389row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5d6e7194_baae_11eb_b74e_a860b6348389row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d6e7194_baae_11eb_b74e_a860b6348389row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5d6e7194_baae_11eb_b74e_a860b6348389row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_5d6e7194_baae_11eb_b74e_a860b6348389" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >O3 AQI</th>        <th class="col_heading level0 col1" >Death</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5d6e7194_baae_11eb_b74e_a860b6348389level0_row0" class="row_heading level0 row0" >O3 AQI</th>
#                         <td id="T_5d6e7194_baae_11eb_b74e_a860b6348389row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_5d6e7194_baae_11eb_b74e_a860b6348389row0_col1" class="data row0 col1" >0.543550</td>
#             </tr>
#             <tr>
#                         <th id="T_5d6e7194_baae_11eb_b74e_a860b6348389level0_row1" class="row_heading level0 row1" >Death</th>
#                         <td id="T_5d6e7194_baae_11eb_b74e_a860b6348389row1_col0" class="data row1 col0" >0.543550</td>
#                         <td id="T_5d6e7194_baae_11eb_b74e_a860b6348389row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
print(f"The r-value for Ozone (O3) is: {rvalue}")
# Out:
# The r-value for Ozone (O3) is: 0.5435496110691815
