# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
# Importing data files
pollution_data_df = pd.read_csv("../Resources/california_pollution.csv")
mortality_data_df1 = pd.read_csv("../Resources/california_mortality_1.csv")
mortality_data_df2 = pd.read_csv("../Resources/california_mortality_2.csv")

# %%
pollution_data_df.head()
# Out:
#    Unnamed: 0  State Code  County Code  Site Num                 Address  \
# 0        3516           6           13         2  2956-A TREAT BOULEVARD
# 1        3517           6           13         2  2956-A TREAT BOULEVARD
# 2        3518           6           13         2  2956-A TREAT BOULEVARD
# 3        3519           6           13         2  2956-A TREAT BOULEVARD
# 4        3520           6           13         2  2956-A TREAT BOULEVARD
#
#         State        County     City Date Local          NO2 Units  ...  \
# 0  California  Contra Costa  Concord     1/1/00  Parts per billion  ...
# 1  California  Contra Costa  Concord     1/1/00  Parts per billion  ...
# 2  California  Contra Costa  Concord     1/1/00  Parts per billion  ...
# 3  California  Contra Costa  Concord     1/1/00  Parts per billion  ...
# 4  California  Contra Costa  Concord     1/2/00  Parts per billion  ...
#
#            SO2 Units  SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour SO2 AQI  \
# ...

# %%
mortality_data_df1.head()
# Out:
#   Notes              County  County Code  Gender Gender Code    Year  \
# 0   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 1   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 2   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 3   NaN  Alameda County, CA       6001.0  Female           F  2007.0
# 4   NaN  Alameda County, CA       6001.0  Female           F  2007.0
#
#    Year Code                       Race Race Code  Deaths  Population  \
# 0     2006.0  Asian or Pacific Islander      A-PI    46.0    204139.0
# 1     2006.0  Black or African American    2054-5    70.0    112599.0
# 2     2006.0                      White    2106-3   330.0    410372.0
# 3     2007.0  Asian or Pacific Islander      A-PI    42.0    209933.0
# 4     2007.0  Black or African American    2054-5    69.0    112100.0
#
#   Crude Rate Age Adjusted Rate  % of Total Deaths
# 0       22.5              27.7              0.000
# ...

# %%
mortality_data_df2.head()
# Out:
#   Notes              County  County Code  Gender Gender Code    Year  \
# 0   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 1   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 2   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 3   NaN  Alameda County, CA       6001.0  Female           F  2006.0
# 4   NaN  Alameda County, CA       6001.0  Female           F  2007.0
#
#    Year Code                              Race Race Code  Deaths  Population  \
# 0     2006.0  American Indian or Alaska Native    1002-5    17.0      9043.0
# 1     2006.0         Asian or Pacific Islander      A-PI   667.0    204139.0
# 2     2006.0         Black or African American    2054-5  1048.0    112599.0
# 3     2006.0                             White    2106-3  3003.0    410372.0
# 4     2007.0  American Indian or Alaska Native    1002-5    19.0      9388.0
#
#            Crude Rate   Age Adjusted Rate  % of Total Deaths
# ...
